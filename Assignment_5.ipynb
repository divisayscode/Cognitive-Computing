# %%
import numpy as np
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
print(np.matrix(gfg))
print(np.sum(gfg))
print(np.sum(gfg, axis=0))# column sum
print(np.sum(gfg, axis=1))# row sum
# Out:
# [[ 4  1  9]
#  [12  3  1]
#  [ 4  5  6]]
# 45
# [[20  9 16]]
# [[14]
#  [16]
#  [15]]

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])
np.sort(array)# this is for sorting an array
np.min(array)# this is for minimum element in array
np.argsort(array)# indices for sorted array
np.sort(array)[:4]# this is for first 4 small elements in ascending order
np.sort(array)[::-1][:5]# this is for first 5 largest elements i
# (b) part of Q2

array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

integer_elements = array[array % 1 == 0]
float_elements = array[array % 1 != 0]

print("Integer elements only:", integer_elements)
print("Float elements only:", float_elements)
# Out:
# Integer elements only: [1. 2. 3. 2.]
# Float elements only: [1.2 2.2]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)


plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title("Y = x²")
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title("Y = sin(x)")
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title("Y = e^x")
plt.ylim(0, 100)
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title("Y = log(|x| + 1)")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np

first = ord('A')
last= ord('B')
X = first+ last
sales = np.array([X, X + 50, X + 100, X + 150, X + 200])

tax_rate = ((X % 5) + 5) / 100
taxed_sales = sales * (1 + tax_rate)

discounted_sales = np.where(sales < X + 100, sales * 0.95, sales * 0.90)

weekly_sales = np.tile(sales, (3, 1))
weekly_sales = weekly_sales * (1 + 0.02 * np.arange(3).reshape(-1, 1))

print("Sales dataset:", sales)
print("Personalized tax rate:", tax_rate)
print("Sales after tax:", taxed_sales)
print("Sales after discount:", discounted_sales)
print("Weekly sales (adjusted for weekly increase):\n", weekly_sales)
# Out:
# Sales dataset: [131 181 231 281 331]
# Personalized tax rate: 0.06
# Sales after tax: [138.86 191.86 244.86 297.86 350.86]
# Sales after discount: [124.45 171.95 207.9  252.9  297.9 ]
# Weekly sales (adjusted for weekly increase):
#  [[131.   181.   231.   281.   331.  ]
#  [133.62 184.62 235.62 286.62 337.62]
#  [136.24 188.24 240.24 292.24 344.24]]
